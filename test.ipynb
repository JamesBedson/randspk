# %%
import SpeakerLayout as sl
import PlotUtils as pu

# %%
speaker_layout = sl.SpeakerLayout(num_speakers=8,
                                  radius=1,
                                  symmetry=True,
                                  hemisphere=True,
                                  random_seed=1234)

layout_t, sph = speaker_layout.generate_random_layout(return_spherical=True)
print(sph)

#pu.plot_speaker_layout(layout)
# Out:
# [[1.2033522  0.89462716 1.        ]
#  [3.90882469 0.27608666 1.        ]
#  [2.7503245  0.28011301 1.        ]
#  [4.93455351 0.93042204 1.        ]]
