# %%
import SpeakerLayout as sl
import PlotUtils as pu

# %%
speaker_layout = sl.SpeakerLayout(num_speakers=8,
                                  radius=1,
                                  symmetry=True,
                                  hemisphere=True,
                                  random_seed=1234)

sph = speaker_layout.generate_random_layout()
sph_deg = speaker_layout.spherical_to_degrees(sph)
print(sph_deg)

pu.plot_speaker_layout(sph)
# Out:
# [[ 335.93043671   18.47169446    1.        ]
#  [ 234.49613156   34.61774516    1.        ]
#  [ 142.99292798   60.35739435    1.        ]
#  [ 283.94285146   25.85998419    1.        ]
#  [-335.93043671   18.47169446    1.        ]
#  [-234.49613156   34.61774516    1.        ]
#  [-142.99292798   60.35739435    1.        ]
#  [-283.94285146   25.85998419    1.        ]]
